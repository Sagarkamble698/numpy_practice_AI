# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
arr=np.array([1,2,3])
print(arr)
# Out:
# [1 2 3]

# %%
import numpy as np

arr = np.array([1, 2, 3])
print(arr)
arr.flatten()
np.expand_dims(arr, axis=0)
# Out:
# [1 2 3]
# array([[1, 2, 3]])

# %%
np.zeros((2,2))
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0, 1, 5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.expand_dims(arr, axis=0)
# Out:
# array([[1, 2, 3]])

# %%
np.random.rand(3,3)
# Out:
# array([[0.61552065, 0.06477925, 0.16472215],
#        [0.43897402, 0.75800373, 0.73009964],
#        [0.37754669, 0.34395755, 0.17814862]])

# %%
np.random.randint(0, 10, size=(2,2))
# Out:
# array([[7, 9],
#        [3, 6]], dtype=int32)

# %%
np.random.randn(3,3)
# Out:
# array([[ 1.08317369,  0.10086173, -1.08561868],
#        [ 0.3115257 ,  1.23552665,  0.54971179],
#        [-1.01363127,  0.58568862, -2.28709611]])

# %%
np.mean(arr)
# Out:
# np.float64(2.0)

# %%
np.std(arr)
# Out:
# np.float64(0.816496580927726)

# %%
np.sum(arr)
# Out:
# np.int64(6)

# %%
np.max(arr)
# Out:
# np.int64(3)

# %%
np.min(arr)
# Out:
# np.int64(1)

# %%
np.argmax([0.1, 0.8, 0.1])
# Out:
# np.int64(1)

# %%
A=np.array([[1,2],[5,7]])
B=np.array([3,4])
np.dot(A, B)
A @ B
# Out:
# array([11, 43])

# %%
A.T
# Out:
# array([[1, 5],
#        [2, 7]])

# %%
np.linalg.inv(A)
# Out:
# array([[-2.33333333,  0.66666667],
#        [ 1.66666667, -0.33333333]])

# %%
np.linalg.eig(A)
# Out:
# EigResult(eigenvalues=array([-0.35889894,  8.35889894]), eigenvectors=array([[-0.82713818, -0.26226628],
#        [ 0.5619986 , -0.96499554]]))

# %%
x=np.array([0,1,2])
np.maximum(0, x)
# Out:
# array([0, 1, 2])

# %%
1 / (1 + np.exp(-x))
# Out:
# array([0.5       , 0.73105858, 0.88079708])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 (data - np.mean(data)) / np.std(data)
#
# NameError: name 'data' is not defined

# %%
exp_x = np.exp(x)

softmax = exp_x / np.sum(exp_x)
